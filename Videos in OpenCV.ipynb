# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import os
from matplotlib import pyplot as plt

# %% [markdown]
# # 2. Setting up a Captures

# %%
cap = cv2.VideoCapture(os.path.join('video-1.mp4'))

# %%
ret, frame = cap.read()

# %%
plt.imshow(cv2.cvtColor(frame, cv2.COLOR_BGR2RGB))
plt.show()

# %%
cap.release()

# %%
cap.read()
# Out:
# (False, None)

# %% [markdown]
# # 3. Capture Properties

# %%
ret, frame = cap.read()

# %%
cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
# Out:
# 0.0

# %%
cap.get(cv2.CAP_PROP_FRAME_WIDTH)
# Out:
# 0.0

# %%
cap.get(cv2.CAP_PROP_FRAME_COUNT)
# Out:
# 0.0

# %%
cap.get(cv2.CAP_PROP_FPS)
# Out:
# 0.0

# %% [markdown]
# # 4. Working with Video Captures

# %%
cap = cv2.VideoCapture(os.path.join('video-1.mp4'))

for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Video Player', gray)
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# # 5. Writing out Videos

# %%
cap = cv2.VideoCapture(os.path.join('video-1.mp4'))

height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
fps = cap.get(cv2.CAP_PROP_FPS)

video_writer = cv2.VideoWriter(os.path.join('video-2.mp4'), cv2.VideoWriter_fourcc('P','I','M','1'), fps, (width, height), isColor=False) 
                                                                                        
for frame_idx in range(int(cap.get(cv2.CAP_PROP_FRAME_COUNT))):
    
    ret, frame = cap.read()
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Video Player', gray)
    video_writer.write(gray)
    if cv2.waitKey(0):
        break

cap.release()
cv2.destroyAllWindows()

video_writer.release()
# Out:
# OpenCV: FFMPEG: tag 0x314d4950/'PIM1' is not supported with codec id 1 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
