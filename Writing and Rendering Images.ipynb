# %% [markdown]
# # 1. Import Dependencies

# %%
import cv2
import os

# %% [markdown]
# # 2. Read in Image

# %%
img_path = os.path.join('image-3.jpeg')

# %%
img = cv2.imread(img_path)

# %% [markdown]
# # 3. Render Image

# %%
from matplotlib import pyplot as plt

# %%
plt.imshow(img)

# %%
recolor = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(recolor)
plt.show()

# %% [markdown]
# # 4. Write out Image

# %%
cv2.imwrite('grayimage.jpg', gray)
# Out:
# True

# %%
output_path = os.path.join('data','output', 'outputgray.jpg')

# %%
cv2.imwrite(output_path, gray)
# Out:
# False
